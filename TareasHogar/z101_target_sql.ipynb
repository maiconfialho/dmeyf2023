# %% [markdown]
# # Crear Target
#
# ## Ejercicio 1:
# Cree el archivo `competencia_01.csv`, usando el `competencia_01_crudo.csv` con una variable adicional llamada `clase_ternaria`, que contenga las categorías **CONTINUA**, **BAJA+1** y **BAJA+2**
#
# ### Ayudita
#
# Para practicar el muy útil y necesario lenguaje **SQL**, vamos a utilizar una base de datos **OLAP** llamada **DuckDB**.
#
# La documentación la puede encontrar [aquí](https://duckdb.org/docs/archive/0.8.1/sql/introduction)
# Procedemos a instalarla, esto se debe ejecutar una sola vez

# %%
# %%bash
# pip install duckdb
# pip install jupysql
# pip install duckdb-engine
# Out:
# Requirement already satisfied: duckdb in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (0.8.1)
# Requirement already satisfied: jupysql in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (0.10.0)
# Requirement already satisfied: sqlglot in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from jupysql) (17.14.2)
# Requirement already satisfied: ipython in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from jupysql) (8.10.0)
# Requirement already satisfied: sqlparse in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from jupysql) (0.4.3)
# Requirement already satisfied: jinja2 in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from jupysql) (3.1.2)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from jupysql) (0.2.0)
# Requirement already satisfied: ploomber-core>=0.2.7 in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from jupysql) (0.2.14)
# Requirement already satisfied: prettytable in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from jupysql) (3.8.0)
# Requirement already satisfied: sqlalchemy in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from jupysql) (1.4.39)
# Requirement already satisfied: click in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from ploomber-core>=0.2.7->jupysql) (8.0.4)
# Requirement already satisfied: posthog in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from ploomber-core>=0.2.7->jupysql) (3.0.2)
# Requirement already satisfied: pyyaml in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from ploomber-core>=0.2.7->jupysql) (6.0)
# Requirement already satisfied: traitlets>=5 in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from ipython->jupysql) (5.7.1)
# Requirement already satisfied: pygments>=2.4.0 in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from ipython->jupysql) (2.11.2)
# Requirement already satisfied: pickleshare in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from ipython->jupysql) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from ipython->jupysql) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from ipython->jupysql) (3.0.36)
# Requirement already satisfied: pexpect>4.3 in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from ipython->jupysql) (4.8.0)
# Requirement already satisfied: stack-data in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from ipython->jupysql) (0.2.0)
# Requirement already satisfied: decorator in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from ipython->jupysql) (5.1.1)
# Requirement already satisfied: matplotlib-inline in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from ipython->jupysql) (0.1.6)
# Requirement already satisfied: backcall in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from ipython->jupysql) (0.2.0)
# Requirement already satisfied: appnope in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from ipython->jupysql) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from jinja2->jupysql) (2.1.1)
# Requirement already satisfied: wcwidth in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from prettytable->jupysql) (0.2.5)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from sqlalchemy->jupysql) (2.0.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from jedi>=0.16->ipython->jupysql) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from pexpect>4.3->ipython->jupysql) (0.7.0)
# Requirement already satisfied: backoff>=1.10.0 in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from posthog->ploomber-core>=0.2.7->jupysql) (2.2.1)
# Requirement already satisfied: requests<3.0,>=2.7 in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from posthog->ploomber-core>=0.2.7->jupysql) (2.28.1)
# Requirement already satisfied: monotonic>=1.5 in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from posthog->ploomber-core>=0.2.7->jupysql) (1.6)
# Requirement already satisfied: six>=1.5 in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from posthog->ploomber-core>=0.2.7->jupysql) (1.16.0)
# Requirement already satisfied: python-dateutil>2.1 in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from posthog->ploomber-core>=0.2.7->jupysql) (2.8.2)
# Requirement already satisfied: pure-eval in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from stack-data->ipython->jupysql) (0.2.2)
# Requirement already satisfied: asttokens in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from stack-data->ipython->jupysql) (2.0.5)
# Requirement already satisfied: executing in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from stack-data->ipython->jupysql) (0.8.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (2022.12.7)
# Requirement already satisfied: duckdb-engine in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (0.9.2)
# Requirement already satisfied: duckdb>=0.4.0 in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from duckdb-engine) (0.8.1)
# Requirement already satisfied: sqlalchemy>=1.3.22 in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from duckdb-engine) (1.4.39)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/maiconfialho/anaconda3/lib/python3.10/site-packages (from sqlalchemy>=1.3.22->duckdb-engine) (2.0.1)

# %% [markdown]
# Configuramos el entorno de ejecución. Si ya tiene todo instalado, solo necesita ejecutar esta celda para empezar a usar **duckdb**

# %%
import duckdb
import pandas as pd

# %load_ext sql
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %sql duckdb:///:default:

# %% [markdown]
# Y ya podemos usar **SQL** dentro de una notebook!

# %%
# %%sql
# select 'hola mundo'
# Out:
#   'hola mundo'
# 0   hola mundo

# %% [markdown]
# Para cargar el archivo `.csv` a una tabla:

# %%
# %%sql
# create or replace table competencia_01 as
# select
#     *
# from read_csv_auto('../datasets/competencia_01_crudo.csv')
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#     Count
# 0  491063

# %% [markdown]
# Hagamos unas queries básicas para comprobar que todo esta funcionando bien.

# %%
# %sql select * from competencia_01 limit 5
# Out:
#         numero_de_cliente  foto_mes  active_quarter  cliente_vip  internet  \
# 0                29183981    202103               1            0         0
# 1                29184630    202103               1            0         0
# 2                29185433    202103               1            0         0
# 3                29185587    202103               1            0         0
# 4                29185646    202103               1            0         0
# ...                   ...       ...             ...          ...       ...
# 491058          186790659    202105               0            0         0
# 491059          186792315    202105               1            0         0
# 491060          186795526    202105               1            0         0
# 491061          186798379    202105               0            0         0
# 491062          186836338    202105               0            0         0
#
#         cliente_edad  cliente_antiguedad  mrentabilidad  mrentabilidad_annual  \
# 0                 50                 197       14468.81             125765.29
# 1                 59                 322       11901.57              74158.93
# 2                 68                 268         847.15              21672.47
# 3                 79                 322        4976.94              47735.98
# 4                 60                 257        2860.45              37800.71
# ...              ...                 ...            ...                   ...
# 491058            35                   1           0.00                  0.00
# 491059            37                   1          51.81                 51.81
# 491060            47                   1         327.75                327.75
# 491061            32                   1           0.00                  0.00
# 491062            33                   1          30.73                 30.73
#
#         mcomisiones  ...  Visa_madelantodolares  Visa_fultimo_cierre  \
# 0           2389.82  ...                    0.0                  7.0
# 1          18750.68  ...                    0.0                  1.0
# 2            481.62  ...                    0.0                 21.0
# 3           1839.31  ...                    0.0                  1.0
# 4           4035.40  ...                    0.0                 21.0
# ...             ...  ...                    ...                  ...
# 491058         0.00  ...                    NaN                  5.0
# 491059         0.00  ...                    NaN                  5.0
# 491060         0.00  ...                    NaN                  5.0
# 491061         0.00  ...                    NaN                  5.0
# 491062         0.00  ...                    NaN                  NaN
#
#         Visa_mpagado  Visa_mpagospesos  Visa_mpagosdolares  Visa_fechaalta  \
# 0               0.00        -114954.00                0.00          5938.0
# 1               0.00         -40330.15               17.59          4089.0
# 2            4692.00          -1173.00                0.00          7829.0
# 3               0.00         -15988.67                0.00          7580.0
# 4          380616.14         -97383.25                0.00          7827.0
# ...              ...               ...                 ...             ...
# 491058          0.00               NaN                 NaN            28.0
# 491059          0.00               NaN                 NaN            25.0
# 491060          0.00               NaN                 NaN            21.0
# 491061          0.00               NaN                 NaN            11.0
# 491062          0.00               NaN                 NaN             1.0
#
#         Visa_mconsumototal  Visa_cconsumos  Visa_cadelantosefectivo  \
# 0                101050.66            68.0                      0.0
# 1                 26834.09             7.0                      0.0
# 2                  1651.36             3.0                      0.0
# 3                 30025.29            11.0                      0.0
# 4                359610.70            31.0                      0.0
# ...                    ...             ...                      ...
# 491058                 NaN             NaN                      NaN
# 491059                 NaN             NaN                      NaN
# 491060                 NaN             NaN                      NaN
# 491061                 NaN             NaN                      NaN
# 491062                 NaN             NaN                      NaN
#
#         Visa_mpagominimo
# 0               71811.06
# 1                3894.36
# 2                1560.09
# 3                1700.85
# 4               15600.90
# ...                  ...
# 491058              0.00
# 491059              0.00
# 491060              0.00
# 491061              0.00
# 491062              0.00
#
# [491063 rows x 154 columns]

# %%
# %%sql
# select
#     periodo
#     , count(*) as cantidad -- cuenta cuantos casos hay en cada periodo
#                            -- y lo guarda en un campo llamado cantidad
# from competencia_01
# group by periodo
# Out:
#    foto_mes  cantidad
# 0    202103    163324
# 1    202104    163637
# 2    202105    164102

# %% [markdown]
# Perfecto, ahora cree una nueva tabla con la variable adicional que se le pide. Algunas funciones que le pueden ser útiles:  [where](https://duckdb.org/docs/sql/query_syntax/where), [left join](https://duckdb.org/docs/sql/query_syntax/from), [case statement](https://duckdb.org/docs/sql/expressions/case)

# %%
# %%sql
# select numero_de_cliente, count(periodo)
# from competencia_01
# group by numero_de_cliente
# having count(periodo) = 2
# Out:
#       numero_de_cliente  count(foto_mes)
# 0              29600771                2
# 1              30961066                2
# 2              32082640                2
# 3              32800986                2
# 4              35935324                2
# ...                 ...              ...
# 2316           75836056                2
# 2317           79454290                2
# 2318           77022755                2
# 2319           84606679                2
# 2320           84622691                2
#
# [2321 rows x 2 columns]

# %%
# %%sql
# select *
# from competencia_01
# where numero_de_cliente = 29282120 --29600771
# Out:
#    numero_de_cliente  foto_mes  active_quarter  cliente_vip  internet  \
# 0           29282120    202103               1            0         0
#
#    cliente_edad  cliente_antiguedad  mrentabilidad  mrentabilidad_annual  \
# 0            61                 174        5347.92              44430.08
#
#    mcomisiones  ...  Visa_madelantodolares  Visa_fultimo_cierre  Visa_mpagado  \
# 0      5021.49  ...                    0.0                    1           0.0
#
#    Visa_mpagospesos  Visa_mpagosdolares  Visa_fechaalta  Visa_mconsumototal  \
# 0               0.0                 0.0            5173              199.17
#
#    Visa_cconsumos  Visa_cadelantosefectivo  Visa_mpagominimo
# 0               1                        0            187.68
#
# [1 rows x 154 columns]

# %% [markdown]
# buenas, para el primer ejercicio, traté de encontrar el mayor registro de foto_mes para cada usuario y restar el valor de foto_mes en la base de datos(202105) por el mayor mes_foto del cliente, por lo que si la diferencia es cero, significa que hasta el mes_foto de la base de datos, la persona sigue siendo cliente del banco, para los demás casos utilicé el mayor foto_mes del cliente y lo resté por foto_mes que se encuentra en cada línea, por lo que obtuve los siguientes resultados:
# si la diferencia es 0, significa que la foto_mes es el último mes que el usuario es cliente del banco, por lo que recibe baja+1, si la diferencia es 1, dejará de ser cliente el próximo mes, es decir, baja+2.

# %% [markdown]
# Me di cuenta que la cantidad de baja+1 es mayor que la de los demás compañeros, no sé si entendí bien, pero lo que entendí fue que si tengo un registro de 202103 y 202104 de un cliente, significa que en 202103 estaría con bajo+2 porque en 2 meses no sería mas cliente y en 202104 estaría con bajo+1 porque el próximo mes dejaría de ser cliente

# %%
# %%sql
# create or replace table competencia_01_solucion as
#
# with max_foto_mes as (
#     select numero_de_cliente, max(foto_mes) as max_foto
#     from competencia_01
#     group by numero_de_cliente
# )
# select c.*,
#     case
#         when m.max_foto = 202105 then 'continua'
#         when m.max_foto - c.foto_mes = 0 then 'baja+1'
#         when m.max_foto - c.foto_mes = 1 then 'baja+2'
#     end as clase_ternaria
# from competencia_01 c
#     left join max_foto_mes m on m.numero_de_cliente = c.numero_de_cliente
# Out:
#     Count
# 0  491063

# %% [markdown]
# ## Ejercicio 1.1
#
# * ¿Cuál es la nominalidad de cada clase?
# * ¿Cuál es la proporción del target?

# %%
# %%sql
# select clase_ternaria, count(distinct numero_de_cliente) as cantidad
# from competencia_01_solucion
# group by clase_ternaria
# Out:
#   clase_ternaria  cantidad
# 0       continua    164102
# 1         baja+1      2018
# 2         baja+2       963

# %%
# %%sql
# SELECT clase_ternaria,
#        COUNT(DISTINCT numero_de_cliente) AS cantidad,
#        COUNT(DISTINCT numero_de_cliente) * 1.0 / SUM(COUNT(DISTINCT numero_de_cliente)) OVER () AS proporcion
# FROM competencia_01_solucion
# GROUP BY clase_ternaria;
# Out:
#   clase_ternaria  cantidad  proporcion
# 0       continua    164102    0.982159
# 1         baja+2       963    0.005764
# 2         baja+1      2018    0.012078

# %% [markdown]
# Para guardar a un **.csv** simplemente debe ejecutar la siguiente sentencia

# %%
# %%sql
# COPY competencia_01_solucion TO '../datasets/competencia_01.csv' (FORMAT CSV, HEADER)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#     Count
# 0  491063

# %% [markdown]
# ## Ejercicio 2 - Avanzado
# Use ahora el archivo `ejercicio_target.csv` y calcule para todos los clientes en todos los periodos su **clase_ternaria** al mismo tiempo

# %%
# %%sql
# create or replace table competencia_01_avanzado as
# select
#     *
# from read_csv_auto('../datasets/ejercicio_target.csv')
# Out:
#    Count
# 0    739

# %%
# %%sql
# select *
# from competencia_01_avanzado
# Out:
#      periodo                          nombre
# 0     202110                  Isaac Valverde
# 1     202110        Santiago Córdova Tercero
# 2     202110                 Jerónimo Ocasio
# 3     202110            Isabel Terrazas Hijo
# 4     202110                 Diego Caballero
# ..       ...                             ...
# 734   202203  Srita. Violeta Carrero Segundo
# 735   202203             Valentín Delafuente
# 736   202203              Valeria Candelaria
# 737   202203            Vicente Luna Tercero
# 738   202203             Ximena Rael Segundo
#
# [739 rows x 2 columns]

# %%
# %%sql
# select numero_de_cliente, foto_mes
# from competencia_01
# where numero_de_cliente = 86201398
# Out:
#    numero_de_cliente  foto_mes
# 0           86201398    202103
# 1           86201398    202104
# 2           86201398    202105

# %%
# %%sql
# select nombre, periodo
# from competencia_01_avanzado
# where nombre = 'Sr. Hipólito Estrada'
# group by nombre, periodo
# Out:
#                  nombre  periodo
# 0  Sr. Hipólito Estrada   202202
# 1  Sr. Hipólito Estrada   202203

# %%
# %%sql
# with max_periodo as (
#     select nombre, max(periodo) as max_periodo
#     from competencia_01_avanzado
#     group by nombre
# )
# select c.*, m.max_periodo,
#     case
#         when m.max_periodo = 202203 then 'continua'
#         when m.max_periodo - c.periodo = 0 then 'baja+1'
#         when m.max_periodo - c.periodo = 1 then 'baja+2'
#         when m.max_periodo - c.periodo > 1 then concat('baja+', m.max_periodo - c.periodo)
#     end as clase_ternaria
# from competencia_01_avanzado c
#     left join max_periodo m on m.nombre = c.nombre
# Out:
#      periodo                    nombre  max_periodo clase_ternaria
# 0     202110            Isaac Valverde       202203       continua
# 1     202110  Santiago Córdova Tercero       202112         baja+2
# 2     202110           Jerónimo Ocasio       202203       continua
# 3     202110      Isabel Terrazas Hijo       202203       continua
# 4     202110           Diego Caballero       202110         baja+1
# ..       ...                       ...          ...            ...
# 734   202112          David Villaseñor       202203       continua
# 735   202201          David Villaseñor       202203       continua
# 736   202202          David Villaseñor       202203       continua
# 737   202203          David Villaseñor       202203       continua
# 738   202203      Julia Santacruz Hijo       202203       continua
#
# [739 rows x 4 columns]

# %% [markdown]
# Para el ejercicio avanzado seguí la misma idea que el anterior, las únicas diferencias fueron que no ingresé manualmente el último período de registro y para baja+n ingresé la cantidad de meses que faltan para dejar de ser cliente en lugar de 'n'.
# Como no encontré una función para convertir cadenas en fechas en duckdb, tuve que calcular manualmente la diferencia de meses cuando cuando la resta es entre el primer mes de un año y el último mes del año pasado, por ejemplo: 202212 - 202301

# %%
# %%sql
# create or replace table competencia_01_avanzado_solucion as
#
# with max_db as
#     (
#         select max(periodo) as max_periodo_db
#         from competencia_01_avanzado
#     )
# select c.*, max_db.max_periodo_db, max_nombre.max_periodo, c.periodo,
#     case
#         when max_db.max_periodo_db = max_nombre.max_periodo then 'continua'
#         when CAST(SUBSTRING(max_nombre.max_periodo, 1, 4) AS INTEGER) * 12 + CAST(SUBSTRING(max_nombre.max_periodo, 5, 2) AS INTEGER) -
#            (CAST(SUBSTRING(c.periodo, 1, 4) AS INTEGER) * 12 + CAST(SUBSTRING(c.periodo, 5, 2) AS INTEGER)) =  0 then 'baja+1'
#         when CAST(SUBSTRING(max_nombre.max_periodo, 1, 4) AS INTEGER) * 12 + CAST(SUBSTRING(max_nombre.max_periodo, 5, 2) AS INTEGER) -
#            (CAST(SUBSTRING(c.periodo, 1, 4) AS INTEGER) * 12 + CAST(SUBSTRING(c.periodo, 5, 2) AS INTEGER)) == 1 then 'baja+2'
#          when CAST(SUBSTRING(max_nombre.max_periodo, 1, 4) AS INTEGER) * 12 + CAST(SUBSTRING(max_nombre.max_periodo, 5, 2) AS INTEGER) -
#            (CAST(SUBSTRING(c.periodo, 1, 4) AS INTEGER) * 12 + CAST(SUBSTRING(c.periodo, 5, 2) AS INTEGER)) > 1 then
#             concat('baja+', CAST(SUBSTRING(max_nombre.max_periodo, 1, 4) AS INTEGER) * 12 + CAST(SUBSTRING(max_nombre.max_periodo, 5, 2) AS INTEGER) -
#                             (CAST(SUBSTRING(c.periodo, 1, 4) AS INTEGER) * 12 + CAST(SUBSTRING(c.periodo, 5, 2) AS INTEGER)))
#     end as clase_ternaria,
#     CAST(SUBSTRING(max_nombre.max_periodo, 1, 4) AS INTEGER) * 12 + CAST(SUBSTRING(max_nombre.max_periodo, 5, 2) AS INTEGER) -
#         (CAST(SUBSTRING(c.periodo, 1, 4) AS INTEGER) * 12 + CAST(SUBSTRING(c.periodo, 5, 2) AS INTEGER)) as valor
# from competencia_01_avanzado c
#     cross join max_db
#     left join
#         (
#             select nombre, max(periodo) as max_periodo
#             from competencia_01_avanzado
#             group by nombre
#         ) max_nombre on max_nombre.nombre = c.nombre
# Out:
#    Count
# 0    739

# %%
# %%sql
#
# select clase_ternaria, count(nombre)
# from competencia_01_avanzado_solucion
# group by clase_ternaria
# Out:
#   clase_ternaria  count(nombre)
# 0       continua            649
# 1         baja+2             42
# 2         baja+1             41
# 3         baja+3              5
# 4         baja+4              2

# %%
# %%sql
# COPY competencia_01_avanzado_solucion TO '../datasets/competencia_01_avanzado.csv' (FORMAT CSV, HEADER)
# Out:
#    Count
# 0    739
